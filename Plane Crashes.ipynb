# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Airplane_Crashes.csv')
df
# Out:
#       index        Date   Time  \
# 0         0  09/17/1908  17:18
# 1         1  07/12/1912  06:30
# 2         2  08/06/1913    NaN
# 3         3  09/09/1913  18:30
# 4         4  10/17/1913  10:30
# ...     ...         ...    ...
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
wroute = df[df["Route"].notna()]
wroute.head(20)
# Out:
#      index        Date   Time                        Location  \
# 0        0  09/17/1908  17:18             Fort Myer, Virginia
# 1        1  07/12/1912  06:30         AtlantiCity, New Jersey
# 56      56  09/06/1921    NaN                   Paris, France
# 80      80  12/23/1923  02:30      Over the Mediterranean Sea
# 83      83  04/24/1924    NaN        Over the English Channel
# 96      96  09/03/1925  05:30                  Caldwell, Ohio
# 102    102  07/03/1926    NaN       Rossaugpt, Czechoslovakia
# 106    106  09/26/1926    NaN              New York, New York
# 119    119  08/22/1927  08:30              Sevenoaks, England
# 121    121  09/17/1927    NaN              Hadley, New Jersey
# 123    123  09/23/1927  10:00                Schleiz, Germany
# 132    132  01/08/1928    NaN      Near Canajoharie, New York
# 146    146  06/22/1928    NaN                    Lebo, Kansas
# 148    148  07/13/1928    NaN                 Purley, England
# ...

# %%
wroute["Route"].isna().sum()
# Out:
# 0

# %%
wroute["Flight #"].isna().sum()
# Out:
# 2538
